# %% [markdown]
# # Exercise 1

# %%
titles = pd.read_csv('titles.csv')
titles.head()
# Out:
#                   title  year
# 0    Tasveer Mere Sanam  1996
# 1              Only You  1994
# 2  El pueblo del terror  1970
# 3               Machine  2007
# 4                  MARy  2008

# %% [markdown]
# # How many films are listed in the titles dataframe?

# %%
import pandas as pd

# Assuming you have already read the CSV file into the DataFrame
df = pd.read_csv('titles.csv')

# Use len() to find the number of movies
num_movies = len(df)
print(f'Total number of movies: {num_movies}')
# Out:
# Total number of movies: 244914

# %% [markdown]
# # What are the earliest two films listed in the titles dataframe?

# %%
import pandas as pd

# Assuming you have already read the CSV file into the DataFrame
df = pd.read_csv('titles.csv')

# Sort the DataFrame by release year in ascending order
df_sorted = df.sort_values(by='year')

# Select the first two rows (earliest two films)
earliest_films = df_sorted.head(2)

# Display the earliest two films
print(earliest_films)
# Out:
#                      title  year
# 193222          Miss Jerry  1894
# 51388   The Startled Lover  1898

# %% [markdown]
# # How many movies have the title "Hamlet"?

# %%
import pandas as pd

# Assuming you have already read the CSV file into the DataFrame
df = pd.read_csv('titles.csv')

# Filter the DataFrame for movies with the title "Hamlet"
hamlet_movies = df[df['title'] == 'Hamlet']

# Get the count of Hamlet movies
num_hamlet_movies = len(hamlet_movies)

print(f'Total number of movies with the title "Hamlet": {num_hamlet_movies}')
# Out:
# Total number of movies with the title "Hamlet": 20

# %% [markdown]
# # How many movies are titled "North by Northwest?"

# %%
import pandas as pd

# Assuming you have already read the CSV file into the DataFrame
df = pd.read_csv('titles.csv')

# Filter the DataFrame for movies with the title "North by Northwest"
north_by_northwest_movies = df[df['title'] == 'North by Northwest']

# Get the count of "North by Northwest" movies
num_north_by_northwest_movies = len(north_by_northwest_movies)

print(f'Total number of movies titled "North by Northwest": {num_north_by_northwest_movies}')
# Out:
# Total number of movies titled "North by Northwest": 1

# %% [markdown]
# # when was the first movie titles "Hamlet" made?

# %%
import pandas as pd

# Assuming you have already read the CSV file into the DataFrame
df = pd.read_csv('titles.csv')

# Filter the DataFrame for movies with the title "Hamlet"
hamlet_movies = df[df['title'] == 'Hamlet']

# Sort the filtered DataFrame by year in ascending order
hamlet_movies_sorted = hamlet_movies.sort_values(by='year')

# Get the first row, which represents the earliest "Hamlet" movie
first_hamlet_movie = hamlet_movies_sorted.iloc[0]

# Get the release year of the first "Hamlet" movie
release_year = first_hamlet_movie['year']

print(f'The first movie titled "Hamlet" was made in the year {release_year}.')
# Out:
# The first movie titled "Hamlet" was made in the year 1910.

# %% [markdown]
# # List all of the "Treasure Island" movies from earliest to most recent.

# %%
import pandas as pd

# Assuming you have already read the CSV file into the DataFrame
df = pd.read_csv('titles.csv')

# Filter the DataFrame for movies with the title "Treasure Island"
treasure_island_movies = df[df['title'] == 'Treasure Island']

# Sort the filtered DataFrame by year in ascending order
treasure_island_movies_sorted = treasure_island_movies.sort_values(by='year')

# Display the list of "Treasure Island" movies from earliest to most recent
print(treasure_island_movies_sorted)
# Out:
#                   title  year
# 55686   Treasure Island  1918
# 196514  Treasure Island  1920
# 141822  Treasure Island  1934
# 77354   Treasure Island  1950
# 65051   Treasure Island  1972
# 37238   Treasure Island  1973
# 173051  Treasure Island  1985
# 27076   Treasure Island  1999

# %% [markdown]
# # How many movies were made in the year 1950?

# %%
import pandas as pd

# Assuming you have already read the CSV file into the DataFrame
df = pd.read_csv('titles.csv')

# Filter the DataFrame for movies released in the year 1950
movies_1950 = df[df['year'] == 1950]

# Get the count of movies made in 1950
num_movies_1950 = len(movies_1950)

print(f'The number of movies made in the year 1950 is: {num_movies_1950}')
# Out:
# The number of movies made in the year 1950 is: 1113

# %% [markdown]
# # How many movies were made in the year 1960?

# %%
import pandas as pd

# Assuming you have already read the CSV file into the DataFrame
df = pd.read_csv('titles.csv')

# Filter the DataFrame for movies released in the year 1960
movies_1960 = df[df['year'] == 1960]

# Get the count of movies made in 1960
num_movies_1960 = len(movies_1960)

print(f'The number of movies made in the year 1960 : {num_movies_1960}')
# Out:
# The number of movies made in the year 1960 : 1549

# %% [markdown]
# # How many movies were made from 1950 through 1959?

# %%
import pandas as pd

# Assuming you have already read the CSV file into the DataFrame
df = pd.read_csv('titles.csv')

# Filter the DataFrame for movies released between 1950 and 1959 (inclusive)
movies_1950s = df[(df['year'] >= 1950) & (df['year'] <= 1959)]

# Get the count of movies made from 1950 through 1959
num_movies_1950s = len(movies_1950s)

print(f'The number of movies made from 1950 through 1959 is: {num_movies_1950s}')
# Out:
# The number of movies made from 1950 through 1959 is: 12934

# %% [markdown]
# # In What years has a movie titled "Batman" been released?

# %%
import pandas as pd

# read the CSV file into the DataFrame
df = pd.read_csv('titles.csv')

# Filter the DataFrame for movies with the title "Batman"
batman_movies = df[df['title'] == 'Batman']

# Get the unique release years for "Batman" movies
release_years = batman_movies['year'].unique()

print(f"Years in which a movie titled 'Batman' has been released: {release_years}")
# Out:
# Years in which a movie titled 'Batman' has been released: [1943 1989]

# %% [markdown]
# # How many roles were there in the movie "Inception"?

# %%
import pandas as pd

# read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for the movie "Inception"
inception_cast = df[df['title'] == 'Inception']

# Count the number of unique roles in the "Inception" cast
num_roles_inception = len(inception_cast['character'].unique())

print(f'The number of roles in the movie "Inception" is: {num_roles_inception}')
# Out:
# The number of roles in the movie "Inception" is: 56

# %% [markdown]
# # How many roles in the movie "Inception" are not ranked by an "n" value?

# %%
import pandas as pd

# read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for the movie "Inception"
inception_cast = df[df['title'] == 'Inception']

# Count the number of roles in "Inception" that are not ranked by an "n" value
num_unranked_roles_inception = inception_cast['n'].isnull().sum()

print(f'The number of roles in the movie "Inception" that are not ranked by an "n" value is: {num_unranked_roles_inception}')
# Out:
# The number of roles in the movie "Inception" that are not ranked by an "n" value is: 27

# %% [markdown]
# # But how many roles in the movie "Inception" did receive an "n" value?

# %%
import pandas as pd

# read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for the movie "Inception"
inception_cast = df[df['title'] == 'Inception']

# Count the number of roles in "Inception" that received an "n" value
num_ranked_roles_inception = inception_cast['n'].notnull().sum()

print(f'The number of roles in the movie "Inception" that received an "n" value is: {num_ranked_roles_inception}')
# Out:
# The number of roles in the movie "Inception" that received an "n" value is: 51

# %% [markdown]
# # Display the cast of "North by Northwest" in their correct "n" -value order, ignoring roles that did not earn a numeric "n" value

# %%
import pandas as pd

# read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for the movie "North by Northwest" and where "n" is numeric
north_by_northwest_cast = df[(df['title'] == 'North by Northwest') & (df['n'].notnull())]

# Sort the filtered DataFrame by the "n" values in ascending order
north_by_northwest_cast_sorted = north_by_northwest_cast.sort_values(by='n')

# Display the cast of "North by Northwest" in their correct "n" value order
print(north_by_northwest_cast_sorted[['name', 'n']])
# Out:
#                          name     n
# 871426             Cary Grant   1.0
# 3518333       Eva Marie Saint   2.0
# 1457165           James Mason   3.0
# 3157232   Jessie Royce Landis   4.0
# 356707         Leo G. Carroll   5.0
# 3048272  Josephine Hutchinson   6.0
# 1695173           Philip Ober   7.0
# 1275337         Martin Landau   8.0
# 2447081         Adam Williams   9.0
# 1811387          Edward Platt  10.0
# 665768      Robert Ellenstein  11.0
# 2295714          Les Tremayne  12.0
# 464736        Philip Coolidge  13.0
# 1508344         Patrick McVey  14.0
# 206471           Edward Binns  15.0
# 1384780             Ken Lynch  16.0

# %% [markdown]
# # Display the entire cast, in "n" -order, of the 1972 film "Sleuth"

# %%
import pandas as pd

df = pd.read_csv('cast.csv')

# Filter the DataFrame for the movie "Sleuth" released in 1972
sleuth_1972_cast = df[(df['title'] == 'Sleuth') & (df['year'] == 1972)]

# Sort the filtered DataFrame by the "n" values in ascending order
sleuth_1972_cast_sorted = sleuth_1972_cast.sort_values(by='n')

# Display the entire cast of "Sleuth" (1972) in "n" value order
print(sleuth_1972_cast_sorted[['name', 'n']])
# Out:
#                        name    n
# 1705394    Laurence Olivier  1.0
# 326773        Michael Caine  2.0
# 373876       Alec Cawthorne  3.0
# 1465483  John (II) Matthews  4.0
# 2724553  Eve (III) Channing  5.0
# 1448690        Teddy Martin  6.0

# %% [markdown]
# # Now display the entire cast, in "n" -order, of the 2007 version of "Sleuth"

# %%
import pandas as pd

df = pd.read_csv('cast.csv')

# Filter the DataFrame for the movie "Sleuth" released in 2007
sleuth_2007_cast = df[(df['title'] == 'Sleuth') & (df['year'] == 2007)]

# Sort the filtered DataFrame by the "n" values in ascending order
sleuth_2007_cast_sorted = sleuth_2007_cast.sort_values(by='n')

# Display the entire cast of "Sleuth" (2007) in "n" value order
print(sleuth_2007_cast_sorted[['name', 'n']])
# Out:
#                         name    n
# 326774         Michael Caine  1.0
# 1293634             Jude Law  2.0
# 1805907        Harold Pinter  3.0
# 260242       Kenneth Branagh  NaN
# 373877   Alec (II) Cawthorne  NaN
# 2724552    Eve (II) Channing  NaN
# 3370424    Carmel O'Sullivan  NaN

# %% [markdown]
# # How many roles were credited in the silent 1921 version of Hamlet?

# %%
import pandas as pd

df = pd.read_csv('cast.csv')

# Filter the DataFrame for the silent 1921 version of "Hamlet"
hamlet_1921_cast = df[(df['title'] == 'Hamlet') & (df['year'] == 1921)]

# Count the number of credited roles in the 1921 version of "Hamlet"
num_credited_roles_1921 = len(hamlet_1921_cast)

print(f'The number of credited roles in the silent 1921 version of "Hamlet" is: {num_credited_roles_1921}')
# Out:
# The number of credited roles in the silent 1921 version of "Hamlet" is: 9

# %% [markdown]
# # How many roles were credited in Branagh's 1996 Hamlet?

# %%
import pandas as pd

# read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for Branagh's 1996 version of "Hamlet"
branagh_hamlet_cast = df[(df['title'] == 'Hamlet') & (df['year'] == 1996) & (df['name'] == 'Kenneth Branagh')]

# Get the number of credited roles for Kenneth Branagh in his 1996 "Hamlet" movie
num_credited_roles_branagh_1996 = len(branagh_hamlet_cast)

print(f'The number of roles credited in Kenneth Branagh\'s 1996 "Hamlet" is: {num_credited_roles_branagh_1996}')
# Out:
# The number of roles credited in Kenneth Branagh's 1996 "Hamlet" is: 1

# %% [markdown]
# # How many "Hamlet" roles have been listed in all film credits through history?

# %%
import pandas as pd

# read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for roles in movies titled "Hamlet"
hamlet_roles = df[df['title'] == 'Hamlet']

# Get the number of unique "Hamlet" roles
num_hamlet_roles = len(hamlet_roles['character'].unique())

print(f'The number of "Hamlet" roles listed in all film credits throughout history is: {num_hamlet_roles}')
# Out:
# The number of "Hamlet" roles listed in all film credits throughout history is: 112

# %% [markdown]
# # How many people have played an "Ophelia"?

# %%
import pandas as pd

# read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for roles where the character is "Ophelia"
ophelia_actors = df[df['character'] == 'Ophelia']

# Get the number of unique actors who played the role of "Ophelia"
num_ophelia_actors = len(ophelia_actors['name'].unique())

print(f'The number of people who have played the role of "Ophelia" is: {num_ophelia_actors}')
# Out:
# The number of people who have played the role of "Ophelia" is: 115

# %% [markdown]
# # How many people have played a role called "The Dude"?

# %%
the_dude_actors = df[df['character'] == 'The Dude']

# Get the number of unique actors who played the role of "The Dude"
num_the_dude_actors = len(the_dude_actors['name'].unique())

print(f'The number of people who have played a role called "The Dude" is: {num_the_dude_actors}')
# Out:
# The number of people who have played a role called "The Dude" is: 19

# %% [markdown]
# # How many people have played a role called "The Stranger"?

# %%
the_stranger_actors = df[df['character'] == 'The Stranger']

# Get the number of unique actors who played the role of "The Stranger"
num_the_stranger_actors = len(the_stranger_actors['name'].unique())

print(f'The number of people who have played a role called "The Stranger" is: {num_the_stranger_actors}')
# Out:
# The number of people who have played a role called "The Stranger" is: 202

# %% [markdown]
# # How many roles has Sidney Poitier played throughout his career?

# %%
sidney_poitier_roles = df[df['name'] == 'Sidney Poitier']

# Get the number of unique roles played by Sidney Poitier
num_sidney_poitier_roles = len(sidney_poitier_roles['character'].unique())

print(f'Sidney Poitier has played {num_sidney_poitier_roles} unique roles throughout his career.')
# Out:
# Sidney Poitier has played 41 unique roles throughout his career.

# %% [markdown]
# # How many roles has Judi Dench played?

# %%
judi_dench_roles = df[df['name'] == 'Judi Dench']

# Get the number of unique roles played by judi dench
num_judi_dench_roles = len(judi_dench_roles['character'].unique())

print(f'Judi Dench has played {num_judi_dench_roles} unique roles throughout his career.')
# Out:
# Judi Dench has played 46 unique roles throughout his career.

# %% [markdown]
# # List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year

# %%
# Filter the DataFrame for Cary Grant's supporting roles in the 1940s
cary_grant_supporting_roles = df[(df['name'] == 'Cary Grant') & (df['n'] == 2) & (df['year'] >= 1940) & (df['year'] <= 1949)]

# Sort the filtered DataFrame by year in ascending order
cary_grant_supporting_roles_sorted = cary_grant_supporting_roles.sort_values(by='year')

# Display the supporting roles played by Cary Grant in the 1940s, in order by year
print(cary_grant_supporting_roles_sorted[['year', 'title', 'character']])
# Out:
#         year             title    character
# 871423  1940  My Favorite Wife   Nick Arden
# 871433  1941    Penny Serenade  Roger Adams

# %% [markdown]
# # List the leading roles played by Cary Grant in the 1940s, in order by year

# %%
# Filter the DataFrame for Cary Grant's leading roles in the 1940s
cary_grant_leading_roles = df[(df['name'] == 'Cary Grant') & (df['n'] == 1) & (df['year'] >= 1940) & (df['year'] <= 1949)]

# Sort the filtered DataFrame by year in ascending order
cary_grant_leading_roles_sorted = cary_grant_leading_roles.sort_values(by='year')

# Display the leading roles played by Cary Grant 
print(cary_grant_leading_roles_sorted[['year', 'title', 'character']])
# Out:
#         year                                 title  \
# 871448  1940               The Howards of Virginia
# 871407  1940                       His Girl Friday
# 871450  1940                The Philadelphia Story
# 871438  1941                             Suspicion
# 871452  1942                  The Talk of the Town
# 871429  1942                 Once Upon a Honeymoon
# 871398  1943                     Destination Tokyo
# 871422  1943                             Mr. Lucky
# 871430  1944                      Once Upon a Time
# 871390  1944                  Arsenic and Old Lace
# 871425  1944             None But the Lonely Heart
# 871424  1946                         Night and Day
# 871427  1946                             Notorious
# 871444  1947      The Bachelor and the Bobby-Soxer
# 871445  1947                     The Bishop's Wife
# 871421  1948  Mr. Blandings Builds His Dream House
# 871402  1948          Every Girl Should Be Married
# ...

# %% [markdown]
# # How many roles were available for actors in the 1950s?

# %%
# Filter the DataFrame for roles in the 1950s
roles_in_1950s = df[(df['year'] >= 1950) & (df['year'] <= 1959)]

# Count the total number of roles available for actors in the 1950s
num_roles_in_1950s = len(roles_in_1950s)

print(f'The total number of roles available for actors in the 1950s is: {num_roles_in_1950s}')
# Out:
# The total number of roles available for actors in the 1950s is: 215471

# %% [markdown]
# # How many roles were available for actresses in the 1950s?

# %%
import pandas as pd

# Read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for roles played by actresses in the 1950s
actress_roles_in_1950s = df[(df['year'] >= 1950) & (df['year'] <= 1959) & (df['type'] == 'actress')]

# Count the total number of roles available for actresses in the 1950s
num_actress_roles_in_1950s = len(actress_roles_in_1950s)

print(f'The total number of roles available for actresses in the 1950s is: {num_actress_roles_in_1950s}')
# Out:
# The total number of roles available for actresses in the 1950s is: 57733

# %% [markdown]
# # How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
import pandas as pd

# Read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for leading roles (n=1) through 1980
leading_roles_through_1980 = df[(df['n'] == 1) & (df['year'] <= 1980)]

# Count the total number of leading roles available through 1980
num_leading_roles_through_1980 = len(leading_roles_through_1980)

print(f'The total number of leading roles (n=1) available through 1980 is: {num_leading_roles_through_1980}')
# Out:
# The total number of leading roles (n=1) available through 1980 is: 65140

# %% [markdown]
# # How many non-leading roles were available from the beginning of film history through 1980?

# %%
import pandas as pd

# Read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for non-leading roles (n is not equal to 1) through 1980
non_leading_roles_through_1980 = df[(df['n'] != 1) & (df['year'] <= 1980)]

# Count the total number of non-leading roles 
num_non_leading_roles_through_1980 = len(non_leading_roles_through_1980)

print(f'The total number of non-leading roles available through 1980 is: {num_non_leading_roles_through_1980}')
# Out:
# The total number of non-leading roles available through 1980 is: 1117667

# %% [markdown]
# # how many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
import pandas as pd

#Read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for roles with a null "n" value through 1980
roles_without_numeric_n_through_1980 = df[(df['n'].isnull()) & (df['year'] <= 1980)]

# Count the total number of roles without a numeric "n" rank through 1980
num_roles_without_numeric_n_through_1980 = len(roles_without_numeric_n_through_1980)

print(f'The total number of roles through 1980 that did not warrant a numeric "n" rank is: {num_roles_without_numeric_n_through_1980}')
# Out:
# The total number of roles through 1980 that did not warrant a numeric "n" rank is: 448347

# %% [markdown]
# # Exercise 2

# %% [markdown]
# # what are the ten most common movie name of all time?

# %%
title_counts = df['title'].value_counts()

#top ten most common movie titles
top_ten_common_titles = title_counts.head(10)

print("The ten most common movie titles of all time are:")
print(top_ten_common_titles)
# Out:
# The ten most common movie titles of all time are:
# Around the World in 80 Days           1364
# Hello Au Revoir                        726
# 7 cajas                                689
# Thelma                                 593
# The Ten Commandments                   536
# The Eschatrilogy: Book of the Dead     517
# Cockneys vs Zombies                    496
# Catching Faith                         492
# The Dark Knight Rises                  458
# The Buccaneer                          437
# Name: title, dtype: int64

# %% [markdown]
# # Which three years of the 1930s saw the most films released?

# %%
movies_1930s = df[(df['year'] >= 1930) & (df['year'] <= 1939)]
movie_counts_by_year = movies_1930s['year'].value_counts()

top_three_years_1930s = movie_counts_by_year.head(3)

print("The three years in the 1930s with the most films released are:")
print(top_three_years_1930s)
# Out:
# The three years in the 1930s with the most films released are:
# 1937    1224
# 1936    1169
# 1938    1163
# Name: year, dtype: int64

# %% [markdown]
# # Plot the number of films that have beenreleased each decade over the history of cinema?

# %%
df['year'] = df['year'] // 10 * 10  # Group years into decades

# Group the DataFrame by decade and count the number of films in each decade
film_counts_by_decade = df['year'].value_counts().sort_index()

# Create a bar plot to visualize the number of films released each decade
plt.figure(figsize=(12, 6))
film_counts_by_decade.plot(kind='bar', color='skyblue')
plt.title('Number of Films Released Each Decade')
plt.xlabel('Decade')
plt.ylabel('Number of Films')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # plot the number of "Hamlet" films made each decade.

# %%
# Filter the DataFrame for movies with the title "Hamlet"
hamlet_movies = df[df['title'] == 'Hamlet']

# Extract the year information from the "year" column
hamlet_movies['year'] = hamlet_movies['year'] // 10 * 10  # Group years into decades

# Group the filtered DataFrame by decade and count the number of "Hamlet" films in each decade
hamlet_counts_by_decade = hamlet_movies['year'].value_counts().sort_index()

# Create a bar plot to visualize the number of "Hamlet" films made each decade
plt.figure(figsize=(12, 6))
hamlet_counts_by_decade.plot(kind='bar', color='skyblue')
plt.title('Number of "Hamlet" Films Made Each Decade')
plt.xlabel('Decade')
plt.ylabel('Number of Films')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_12704\3383267401.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hamlet_movies['year'] = hamlet_movies['year'] // 10 * 10  # Group years into decades

# %% [markdown]
# # plot the number of "Rustler" character in each decade of the history of cinema

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for rows where the character is "Rustler"
rustler_characters = df[df['character'] == 'Rustler']

# Extract the year information from the "year" column
rustler_characters['year'] = rustler_characters['year'] // 10 * 10  # Group years into decades

# Group the filtered DataFrame by decade and count the number of "Rustler" characters in each decade
rustler_character_counts_by_decade = rustler_characters.groupby('year')['character'].count()

# Create a bar plot to visualize the number of "Rustler" characters in each decade
plt.figure(figsize=(12, 6))
rustler_character_counts_by_decade.plot(kind='bar', color='skyblue')
plt.title('Number of "Rustler" Characters in Each Decade')
plt.xlabel('Decade')
plt.ylabel('Number of "Rustler" Characters')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_12704\2277526734.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rustler_characters['year'] = rustler_characters['year'] // 10 * 10  # Group years into decades

# %% [markdown]
# # plot the number of "Hamlet" characters made each decade.

# %%
hamlet_cast = df[df['title'] == 'Hamlet']

# Extract the year information from the "year" column
hamlet_cast['year'] = hamlet_cast['year'] // 10 * 10  # Group years into decades

# Group the filtered DataFrame by decade and count the number of unique "Hamlet" characters in each decade
hamlet_character_counts_by_decade = hamlet_cast.groupby('year')['character'].nunique()

# Create a bar plot to visualize the number of "Hamlet" characters made each decade
plt.figure(figsize=(12, 6))
hamlet_character_counts_by_decade.plot(kind='bar', color='skyblue')
plt.title('Number of "Hamlet" Characters Made Each Decade')
plt.xlabel('Decade')
plt.ylabel('Number of Characters')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_12704\1557925744.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hamlet_cast['year'] = hamlet_cast['year'] // 10 * 10  # Group years into decades

# %% [markdown]
# # What are the 11 most common character names in movie history?

# %%
character_name_counts = df['character'].value_counts()
top_11_common_character_names = character_name_counts.head(11)

print("The 11 most common character names in movie history are:")
print(top_11_common_character_names)
# Out:
# The 11 most common character names in movie history are:
# Himself        20746
# Dancer         12477
# Extra          11948
# Reporter        8434
# Student         7773
# Doctor          7669
# Party Guest     7245
# Policeman       7029
# Nurse           6999
# Bartender       6802
# Herself         6705
# Name: character, dtype: int64

# %% [markdown]
# # who are the 10 people most often credited as "Herself" in film history?

# %%
# Filter the DataFrame for rows where the character is "Herself"
herself_credits = df[df['character'] == 'Herself']
herself_credit_counts = herself_credits['name'].value_counts()

top_10_herself_credits = herself_credit_counts.head(10)

print("The 10 people most often credited as 'Herself' in film history are:")
print(top_10_herself_credits)
# Out:
# The 10 people most often credited as 'Herself' in film history are:
# Queen Elizabeth II           12
# Joyce Brothers                9
# Luisa Horga                   9
# Mar?a Luisa (V) Mart?n        9
# Margaret Thatcher             8
# Hillary Clinton               8
# In?s J. Southern              6
# Mar?a Isabel (III) Mart?n     6
# Marta Berrocal                6
# Sumie Sakai                   6
# Name: name, dtype: int64

# %% [markdown]
# # who are the 10 people most often credited as "Himself" in film history?

# %%
himself_credits = df[df['character'] == 'Himself']

# Group the filtered DataFrame by the "name" column and count the occurrences of each name
himself_credit_counts = himself_credits['name'].value_counts()

# Get the top 10 people most often credited as "Himself"
top_10_himself_credits = himself_credit_counts.head(10)

print("The 10 people most often credited as 'Himself' in film history are:")
print(top_10_himself_credits)
# Out:
# The 10 people most often credited as 'Himself' in film history are:
# Adolf Hitler             99
# Richard Nixon            44
# Ronald Reagan            41
# John F. Kennedy          37
# George W. Bush           25
# Winston Churchill        24
# Martin Luther King       23
# Ron Jeremy               22
# Bill Clinton             22
# Franklin D. Roosevelt    21
# Name: name, dtype: int64

# %% [markdown]
# # which actors or actresses appeared in the most movies in the year 1945?

# %%
# Filter the DataFrame for rows with the year 1945
movies_1945 = df[df['year'] == 1945]

# Group the DataFrame by the "name" column and count the number of movie appearances for each actor/actress
movie_appearances_1945 = movies_1945['name'].value_counts()

# Get the actor/actress with the most movie appearances in 1945
most_appearances_1945 = movie_appearances_1945.idxmax()
num_appearances_1945 = movie_appearances_1945.max()

print(f"The actor/actress who appeared in the most movies in 1945 is {most_appearances_1945}, with {num_appearances_1945} appearances.")
# Out:
# The actor/actress who appeared in the most movies in 1945 is Emmett Vogan, with 39 appearances.

# %% [markdown]
# # which actors or actresses appeared in the most movies in the year 1985?

# %%
movies_1985 = df[df['year'] == 1985]
movie_appearances_1985 = movies_1985['name'].value_counts()

most_appearances_1985 = movie_appearances_1985.idxmax()
num_appearances_1985 = movie_appearances_1985.max()

print(f"The actor/actress who appeared in the most movies in 1985 is {most_appearances_1985}, with {num_appearances_1985} appearances.")
# Out:
# The actor/actress who appeared in the most movies in 1985 is Mammootty, with 22 appearances.

# %% [markdown]
# # Plot how many roles Mamootty has played in each year of his career

# %%
mammootty_roles = df[df['name'] == 'Mammootty']
mammootty_role_counts_by_year = mammootty_roles['year'].value_counts().sort_index()

# Create a plot 
plt.figure(figsize=(12, 6))
mammootty_role_counts_by_year.plot(kind='line', color='blue')
plt.title('Number of Roles Played by Mammootty Each Year')
plt.xlabel('Year')
plt.ylabel('Number of Roles')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # What are the 10 most frequent roles that start with the phrase "Patron in"?

# %%
patron_in_roles = df[df['character'].str.startswith('Patron in')]
patron_in_role_counts = patron_in_roles['character'].value_counts()

top_10_patron_in_roles = patron_in_role_counts.head(10)

print("The 10 most frequent roles that start with 'Patron in' are:")
print(top_10_patron_in_roles)
# Out:
# The 10 most frequent roles that start with 'Patron in' are:
# Patron in Frisky Rabbit         16
# Patron in Chinese Restaurant     9
# Patron in the Coffee House       9
# Patron in Billiard Parlor        5
# Patron in restaurant             4
# Patron in Bar                    4
# Patron in cabaret                3
# Patron in Restaurant             3
# Patron in Club                   3
# Patron in booth                  2
# Name: character, dtype: int64

# %% [markdown]
# # what are the 10 most frequent roles that start with the word "Science"?

# %%
science_roles = df[df['character'].str.startswith('Science')]
science_role_counts = science_roles['character'].value_counts()

#top 10 most frequent roles that start with "Science"
top_10_science_roles = science_role_counts.head(10)

print("The 10 most frequent roles that start with 'Science' are:")
print(top_10_science_roles)
# Out:
# The 10 most frequent roles that start with 'Science' are:
# Science Teacher         60
# Science Student          9
# Science Fair Student     9
# Science Fair Judge       6
# Science Fair Kid         5
# Science Reporter         5
# Science Kid              5
# Science Club Member      5
# Science Promo Cadet      5
# Science                  4
# Name: character, dtype: int64

# %% [markdown]
# # plot the -n values of the roles that judi Dench has played played over her career.

# %%
judi_dench_roles = df[df['name'] == 'Judi Dench']

judi_dench_roles = judi_dench_roles.dropna(subset=['n'])

# Extract the "-n" values from the "n" column
n_values = judi_dench_roles['n']

# Create a graph
plt.figure(figsize=(10, 6))
plt.hist(n_values, bins=20, color='skyblue', edgecolor='black')
plt.title('-n Values of Roles Played by Judi Dench')
plt.xlabel('-n Value')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # plot the -n values of Cary Grant's roles his career.

# %%
cary_grant_roles = df[df['name'] == 'Cary Grant']

# Filter out rows with NaN (missing) values in the "n" column
cary_grant_roles = cary_grant_roles.dropna(subset=['n'])
n_values = cary_grant_roles['n']

# Creating a graph
plt.figure(figsize=(10, 6))
plt.hist(n_values, bins=20, color='skyblue', edgecolor='black')
plt.title('-n Values of Roles Played by Cary Grant')
plt.xlabel('-n Value')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # plot the n- values of the roles that Sidney Poitier has acted over the years

# %%
sidney_poitier_roles = df[df['name'] == 'Sidney Poitier']

# Filter out rows with NaN (missing) values in the "n" column
sidney_poitier_roles = sidney_poitier_roles.dropna(subset=['n'])

# Extract the "n" values from the "n" column
n_values = sidney_poitier_roles['n']

# Create a line plot to visualize the "n" values over the years
plt.figure(figsize=(10, 6))
plt.plot(sidney_poitier_roles['year'], n_values, marker='o', linestyle='-', color='skyblue')
plt.title('n Values of Roles Played by Sidney Poitier Over the Years')
plt.xlabel('Year')
plt.ylabel('n Value')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # How many leading (n=1) roles were available to actors, and how many to actresses, in the 1950s?

# %%
roles_1950s = df[(df['year'] >= 1950) & (df['year'] <= 1959)]

actors_leading_roles_1950s = roles_1950s[(roles_1950s['n'] == 1) & (roles_1950s['type'] == 'actor')]
actresses_leading_roles_1950s = roles_1950s[(roles_1950s['n'] == 1) & (roles_1950s['type'] == 'actress')]

num_actors_leading_roles_1950s = len(actors_leading_roles_1950s)
num_actresses_leading_roles_1950s = len(actresses_leading_roles_1950s)

print(f"Number of leading roles (n=1) for actors in the 1950s: {num_actors_leading_roles_1950s}")
print(f"Number of leading roles (n=1) for actresses in the 1950s: {num_actresses_leading_roles_1950s}")
# Out:
# Number of leading roles (n=1) for actors in the 1950s: 6692
# Number of leading roles (n=1) for actresses in the 1950s: 3040

# %% [markdown]
# # How many supporting (n=2) roles were available to actors, and how many to actresses, in the 1950s?

# %%
actors_supporting_roles_1950s = roles_1950s[(roles_1950s['n'] == 2) & (roles_1950s['type'] == 'actor')]
actresses_supporting_roles_1950s = roles_1950s[(roles_1950s['n'] == 2) & (roles_1950s['type'] == 'actress')]

num_actors_supporting_roles_1950s = len(actors_supporting_roles_1950s)
num_actresses_supporting_roles_1950s = len(actresses_supporting_roles_1950s)

print(f"Number of supporting roles (n=2) for actors in the 1950s: {num_actors_supporting_roles_1950s}")
print(f"Number of supporting roles (n=2) for actresses in the 1950s: {num_actresses_supporting_roles_1950s}")
# Out:
# Number of supporting roles (n=2) for actors in the 1950s: 4640
# Number of supporting roles (n=2) for actresses in the 1950s: 4635

# %% [markdown]
# # Exercise 3

# %% [markdown]
# # Use groupby(), plot the number of films that have been released each decade in the history of cinema

# %%
df['decade'] = (df['year'] // 10) * 10
films_by_decade = df.groupby('decade').size()

# Create a bar plot to visualize the number of films released each decade
plt.figure(figsize=(12, 6))
films_by_decade.plot(kind='bar', color='skyblue')
plt.title('Number of Films Released Each Decade in the History of Cinema')
plt.xlabel('Decade')
plt.ylabel('Number of Films')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Use groupby() to plot the number of "Hamlet" films made each decade?

# %%
hamlet_movies = df[df['title'] == 'Hamlet']
hamlet_movies['decade'] = (hamlet_movies['year'] // 10) * 10

# Group the DataFrame by the "decade" column and count the number of "Hamlet" films in each decade
hamlet_movies_by_decade = hamlet_movies.groupby('decade').size()

# Create a bar plot to visualize the number of "Hamlet" films made each decade
plt.figure(figsize=(12, 6))
hamlet_movies_by_decade.plot(kind='bar', color='skyblue')
plt.title('Number of "Hamlet" Films Made Each Decade')
plt.xlabel('Decade')
plt.ylabel('Number of Films')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_12704\1873198614.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hamlet_movies['decade'] = (hamlet_movies['year'] // 10) * 10

# %% [markdown]
# # How many leading (n=1) roles were available to actors, and how many to actresses, in the 1950s?

# %%
roles_1950s = df[(df['year'] >= 1950) & (df['year'] <= 1959)]

actors_leading_roles_1950s = roles_1950s[(roles_1950s['n'] == 1) & (roles_1950s['type'] == 'actor')]
actresses_leading_roles_1950s = roles_1950s[(roles_1950s['n'] == 1) & (roles_1950s['type'] == 'actress')]

num_actors_leading_roles_1950s = len(actors_leading_roles_1950s)
num_actresses_leading_roles_1950s = len(actresses_leading_roles_1950s)

print(f"Number of leading roles (n=1) for actors in the 1950s: {num_actors_leading_roles_1950s}")
print(f"Number of leading roles (n=1) for actresses in the 1950s: {num_actresses_leading_roles_1950s}")
# Out:
# Number of leading roles (n=1) for actors in the 1950s: 6692
# Number of leading roles (n=1) for actresses in the 1950s: 3040

# %% [markdown]
# # In the 1950s decade taken as a whole, how many total roles were available to actors, and actresses, for each "n" number 1 through 5?

# %%
roles_1950s = df[(df['year'] >= 1950) & (df['year'] <= 1959)]

roles_by_n_and_type = roles_1950s.groupby(['n', 'type']).size().unstack(fill_value=0)

# get the counts 
actors_counts = roles_by_n_and_type.loc[[1, 2, 3, 4, 5], 'actor']
actresses_counts = roles_by_n_and_type.loc[[1, 2, 3, 4, 5], 'actress']

print("Total roles available to actors in the 1950s:")
print(actors_counts)

print("\nTotal roles available to actresses in the 1950s:")
print(actresses_counts)
# Out:
# Total roles available to actors in the 1950s:
# n
# 1.0    6692
# 2.0    4640
# 3.0    5654
# 4.0    5663
# 5.0    5674
# Name: actor, dtype: int64
#
# Total roles available to actresses in the 1950s:
# n
# 1.0    3040
# 2.0    4635
# 3.0    3201
# 4.0    2881
# 5.0    2592
# Name: actress, dtype: int64

# %% [markdown]
# # Use groupby() to determine how many roles are listed for each of the Pink Panther movies.

# %%
pink_panther_movies = df[df['title'].str.contains('Pink Panther', case=False)]

# Group the DataFrame by the "title" column and count the number of roles for each movie
roles_by_pink_panther_movie = pink_panther_movies.groupby('title').size()

# Print the number of roles for each Pink Panther movie
print("Number of roles listed for each Pink Panther movie:")
print(roles_by_pink_panther_movie)
# Out:
# Number of roles listed for each Pink Panther movie:
# title
# Curse of the Pink Panther          67
# Revenge of the Pink Panther        68
# Son of the Pink Panther            46
# The Pink Panther                  111
# The Pink Panther 2                 84
# The Pink Panther Strikes Again     70
# The Return of the Pink Panther     30
# Trail of the Pink Panther          41
# dtype: int64

# %% [markdown]
# # List, in order by year, each of the films in which Frank Oz has played more than 1 role

# %%
frank_oz_roles = df[df['name'] == 'Frank Oz']

roles_by_film = frank_oz_roles.groupby(['title', 'year']).size().reset_index(name='role_count')

films_with_multiple_roles = roles_by_film[roles_by_film['role_count'] > 1]
films_with_multiple_roles_sorted = films_with_multiple_roles.sort_values(by='year')

print(films_with_multiple_roles_sorted[['year', 'title', 'role_count']])
# Out:
#     year                                 title  role_count
# 24  1979                      The Muppet Movie           8
# 0   1981        An American Werewolf in London           2
# 22  1981                The Great Muppet Caper           6
# 20  1982                      The Dark Crystal           2
# 25  1984            The Muppets Take Manhattan           7
# 2   1985                      Follow That Bird           3
# 23  1992            The Muppet Christmas Carol           7
# 7   1996                Muppet Treasure Island           4
# 8   1999                    Muppets from Space           4
# 18  1999  The Adventures of Elmo in Grouchland           3

# %% [markdown]
# # List each of the characters that Frank Oz has portrayed atleast twice.

# %%
frank_oz_roles = df[df['name'] == 'Frank Oz']

# Group the filtered DataFrame by the "character" column and count the number of times each character was portrayed
character_counts = frank_oz_roles['character'].value_counts()

# Filter the characters that Frank Oz portrayed at least twice
characters_portrayed_at_least_twice = character_counts[character_counts >= 2]

# Display the list of characters
print("Characters portrayed at least twice by Frank Oz:")
print(characters_portrayed_at_least_twice)
# Out:
# Characters portrayed at least twice by Frank Oz:
# Miss Piggy        6
# Yoda              6
# Animal            6
# Cookie Monster    5
# Sam the Eagle     5
# Fozzie Bear       4
# Bert              3
# Grover            2
# Name: character, dtype: int64

# %% [markdown]
# # Exercise 4

# %% [markdown]
# # Define a year as a "Superman year" whose films feature more Superman characters than Batman. How many years in film history have been Superman years?

# %%
superman_batman_roles = df[(df['character'] == 'Superman') | (df['character'] == 'Batman')]

yearly_character_counts = superman_batman_roles.groupby(['year', 'character']).size().unstack(fill_value=0)

# Calculate the difference between Superman and Batman characters for each year
yearly_superman_minus_batman = yearly_character_counts['Superman'] - yearly_character_counts['Batman']

# Count the number of years where Superman characters outnumber Batman characters
superman_years = len(yearly_superman_minus_batman[yearly_superman_minus_batman > 0])

print(f"Number of years in film history have been 'Superman years': {superman_years}")
# Out:
# Number of years in film history have been 'Superman years': 11

# %% [markdown]
# # How many years have been "Batman years", with more Batman characters than Superman characters?

# %%
import pandas as pd
df = pd.read_csv('cast.csv')

superman_batman_roles = df[(df['character'] == 'Superman') | (df['character'] == 'Batman')]
yearly_character_counts = superman_batman_roles.groupby(['year', 'character']).size().unstack(fill_value=0)

yearly_batman_minus_superman = yearly_character_counts['Batman'] - yearly_character_counts['Superman']

# Count the number of years
batman_years = len(yearly_batman_minus_superman[yearly_batman_minus_superman > 0])

print(f"Number of 'Batman years' with more Batman characters than Superman characters: {batman_years}")
# Out:
# Number of 'Batman years' with more Batman characters than Superman characters: 27

# %% [markdown]
# # Plot the number of actor roles each year and the number of actress roles each year over the history of film

# %%
roles_by_year_and_type = df.groupby(['year', 'type']).size().unstack(fill_value=0)

# Create a line plot to visualize the number of actor roles and actress roles each year
plt.figure(figsize=(12, 6))
plt.plot(roles_by_year_and_type.index, roles_by_year_and_type['actor'], label='Actor', color='skyblue')
plt.plot(roles_by_year_and_type.index, roles_by_year_and_type['actress'], label='Actress', color='salmon')
plt.title('Number of Actor and Actress Roles Each Year')
plt.xlabel('Year')
plt.ylabel('Number of Roles')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the number of actor roles each year and the number of actress roles each year, but this time as a kind = 'area' plot

# %%
roles_by_year_and_type = df.groupby(['year', 'type']).size().unstack(fill_value=0)

# Create an area plot to visualize the number of actor roles and actress roles each year
plt.figure(figsize=(12, 6))
roles_by_year_and_type.plot(kind='area', stacked=True, colormap='coolwarm')
plt.title('Number of Actor and Actress Roles Each Year (Area Plot)')
plt.xlabel('Year')
plt.ylabel('Number of Roles')
plt.legend(['Actor', 'Actress'])
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the difference between number of actor roles each year and the number of actress roles each year over the history of film

# %%
roles_by_year_and_type = df.groupby(['year', 'type']).size().unstack(fill_value=0)

# Calculate the difference between the number of actor and actress roles each year
role_difference = roles_by_year_and_type['actor'] - roles_by_year_and_type['actress']

# Create a line plot to visualize the difference between actor and actress roles each year
plt.figure(figsize=(12, 6))
plt.plot(role_difference.index, role_difference, color='purple')
plt.axhline(y=0, color='gray', linestyle='--', linewidth=1)
plt.title('Difference Between Actor and Actress Roles Each Year')
plt.xlabel('Year')
plt.ylabel('Difference (Actor - Actress)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the fraction of roles that have been 'actor' roles each year in the history of film.

# %%
roles_by_year_and_type = df.groupby(['year', 'type']).size().unstack(fill_value=0)

# Calculate the total number of roles
total_roles_each_year = roles_by_year_and_type.sum(axis=1)

# Calculate the fraction of 'actor' roles each year
actor_fraction_each_year = roles_by_year_and_type['actor'] / total_roles_each_year

# Create a line plot to visualize the fraction of 'actor' roles each year
plt.figure(figsize=(12, 6))
plt.plot(actor_fraction_each_year.index, actor_fraction_each_year, color='blue')
plt.title('Fraction of "Actor" Roles Each Year')
plt.xlabel('Year')
plt.ylabel('Fraction of "Actor" Roles')
plt.ylim(0, 1)  # Set the y-axis limits to be between 0 and 1
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # plot the fraction of supporting(n=2) roles that have been'actor' roles each year in the history of film

# %%
actor_supporting_roles = df[(df['type'] == 'actor') & (df['n'] == 2)]

# Group the filtered DataFrame by "year" and count the number of roles for each year
roles_by_year = actor_supporting_roles.groupby('year').size()

# Group the entire DataFrame by "year" and count the total number of roles (both actor and actress) each year
total_roles_by_year = df.groupby('year').size()

# Calculate the fraction of supporting (n=2) 'actor' roles each year
fraction_supporting_actor_each_year = roles_by_year / total_roles_by_year

# Create a line plot to visualize the fraction of supporting (n=2) 'actor' roles each year
plt.figure(figsize=(12, 6))
plt.plot(fraction_supporting_actor_each_year.index, fraction_supporting_actor_each_year, color='green')
plt.title('Fraction of Supporting (n=2) "Actor" Roles Each Year')
plt.xlabel('Year')
plt.ylabel('Fraction of Supporting (n=2) "Actor" Roles')
plt.ylim(0, 1)  # Set the y-axis limits to be between 0 and 1
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # build a plot with a line for each rank n=1 through n=3, where the line shows what fraction of that rank's roles were 'actor' roles for each year in the history of film

# %%
actor_roles = df[(df['type'] == 'actor') & (df['n'].isin([1, 2, 3]))]

# Group the filtered DataFrame by "year," "n," and count the number of roles for each combination
roles_by_year_and_n = actor_roles.groupby(['year', 'n']).size().unstack(fill_value=0)

# Group the entire DataFrame by "year" and count the total number of roles each year
total_roles_by_year = df.groupby('year').size()

# Calculate the fraction of 'actor' roles for each rank (n=1, 2, 3) each year
fraction_actor_roles_by_rank = roles_by_year_and_n.divide(total_roles_by_year, axis=0)

# Create a plot with lines for each rank (n=1, 2, 3)
plt.figure(figsize=(12, 6))
for n in [1, 2, 3]:
    plt.plot(fraction_actor_roles_by_rank.index, fraction_actor_roles_by_rank[n], label=f'n={n}')
plt.title('Fraction of "Actor" Roles by Rank (n=1, 2, 3) Each Year')
plt.xlabel('Year')
plt.ylabel('Fraction of "Actor" Roles')
plt.ylim(0, 1)  # Set the y-axis limits to be between 0 and 1
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Exercise 5

# %% [markdown]
# # Make a bar plot of months in which movies with "Christmas" in their title tend to be released in the USA.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Filter the DataFrame for rows where the movie title contains "Christmas"
christmas_movies = df[df['title'].str.contains('Christmas', case=False, na=False)]

# Extract the release month and year information from the "year" column
christmas_movies['release_month'] = christmas_movies['year'] % 100

# Group the DataFrame by the "release_month" column and count the number of movies released in each month
movies_by_month = christmas_movies.groupby('release_month').size()

# Create a bar plot to visualize the number of movies released in each month
plt.figure(figsize=(10, 6))
movies_by_month.plot(kind='bar', color='green')
plt.title('Number of Movies with "Christmas" in Title Released in Each Month')
plt.xlabel('Month')
plt.ylabel('Number of Movies')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3864\3919711979.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   christmas_movies['release_month'] = christmas_movies['year'] % 100

# %% [markdown]
# # make a bar  plot of the months in which movies whose titles start with "The Hobbit" are released in USA.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already read the CSV file into the DataFrame
df = pd.read_csv('cast.csv')

# Convert the "title" column to lowercase and filter rows where the movie title starts with "the hobbit" (case-insensitive)
df['title'] = df['title'].str.lower()
hobbit_movies = df[df['title'].str.startswith('the hobbit', na=False)]

# Extract the release year information from the "year" column
hobbit_movies['release_year'] = df['year']

# Group the DataFrame by the "release_year" column and count the number of movies released in each year
movies_by_year = hobbit_movies.groupby('release_year').size()

# Create a bar plot to visualize the number of movies released in each year
plt.figure(figsize=(12, 6))
movies_by_year.plot(kind='bar', color='blue')
plt.title('Number of "The Hobbit" Movies Released Each Year')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3864\777962525.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hobbit_movies['release_year'] = df['year']

# %% [markdown]
# # make a bar plot of the day of the week on which movies with "Romance" in their title tend to be released in the USA.

# %%
df = pd.read_csv('cast.csv')

# Convert the "title" column to lowercase and filter rows where the movie title contains "Romance" (case-insensitive)
df['title'] = df['title'].str.lower()
romance_movies = df[df['title'].str.contains('romance', na=False, case=False)]

# Count the number of "Romance" movies without considering the release date
romance_movie_count = len(romance_movies)

# Create a bar plot to visualize the number of "Romance" movies
plt.figure(figsize=(8, 6))
plt.bar(['Romance'], [romance_movie_count], color='pink')
plt.title('Number of "Romance" Movies')
plt.ylabel('Number of Movies')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # make a bar plot of the day of the week on which movies with "Action" in their title tend to be released in the USA.

# %%
df = pd.read_csv('cast.csv')

# Convert the "title" column to lowercase and filter rows where the movie title contains "Action" (case-insensitive)
df['title'] = df['title'].str.lower()
action_movies = df[df['title'].str.contains('action', na=False, case=False)]

# Count the number of "Action" movies without considering the release date
action_movie_count = len(action_movies)

# Create a bar plot to visualize the number of "Action" movies
plt.figure(figsize=(8, 6))
plt.bar(['Action'], [action_movie_count], color='blue')
plt.title('Number of "Action" Movies')
plt.ylabel('Number of Movies')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # On which date was each judi Dench movie from the 1990s released in the USA?

# %%
judi_dench_1990s = df[(df['name'] == 'Judi Dench') & (df['year'] >= 1990) & (df['year'] <= 1999)]
judi_dench_1990s = judi_dench_1990s[['title', 'year']]
print(judi_dench_1990s)
# Out:
#                            title  year
# 2814219                GoldenEye  1995
# 2814220                   Hamlet  1996
# 2814226             Jack & Sarah  1995
# 2814231                Mrs Brown  1997
# 2814244      Shakespeare in Love  1998
# 2814248       Tea with Mussolini  1999
# 2814256  The World Is Not Enough  1999
# 2814257      Tomorrow Never Dies  1997

# %% [markdown]
# # In which months do films with Judi Dench tend to be released in the USA?

# %%
import pandas as pd

# Load only the relevant rows where the name contains "Judi Dench"
df = pd.read_csv('cast.csv', usecols=['name', 'year'], low_memory=False)
judi_dench_movies = df[df['name'].str.contains('Judi Dench', case=False, na=False)]

# Extract the release month from the 'year' column
judi_dench_movies['ReleaseMonth'] = pd.to_datetime(judi_dench_movies['year'], format='%Y').dt.month

# Count movies by month and print the data
monthly_counts = judi_dench_movies['ReleaseMonth'].value_counts().sort_index()
print("Month\tNumber of Movies")
for month, count in monthly_counts.items():
    print(f"{month}\t{count}")
# Out:
# Month	Number of Movies
# 1	55
# C:\Users\dell\AppData\Local\Temp\ipykernel_3864\280552741.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   judi_dench_movies['ReleaseMonth'] = pd.to_datetime(judi_dench_movies['year'], format='%Y').dt.month

# %%
import pandas as pd

# Load the dataset from cast.csv
df = pd.read_csv('cast.csv')

# Filter for movies with Judi Dench
judi_dench_movies = df[df['name'].str.contains('Judi Dench', case=False, na=False)]

# Extract the release month from the 'year' column
judi_dench_movies['ReleaseMonth'] = pd.to_datetime(judi_dench_movies['year'], format='%Y').dt.month

# Count movies by month and print the data
monthly_counts = judi_dench_movies['ReleaseMonth'].value_counts().sort_index()

# Create a dictionary to map month numbers to month names
month_names = {
    1: 'January',
    2: 'February',
    3: 'March',
    4: 'April',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'August',
    9: 'September',
    10: 'October',
    11: 'November',
    12: 'December'
}

# Print the results
print("Month\tNumber of Movies")
for month, count in monthly_counts.items():
    print(f"{month_names[month]}\t{count}")
# Out:
# Month	Number of Movies
# January	55
# C:\Users\dell\AppData\Local\Temp\ipykernel_3864\1844305088.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   judi_dench_movies['ReleaseMonth'] = pd.to_datetime(judi_dench_movies['year'], format='%Y').dt.month

# %% [markdown]
# # In which months do films with Tom Cruise tend to be released in the USA?

# %%
import pandas as pd

# Load the dataset from cast.csv
df = pd.read_csv('cast.csv')

# Filter for movies with Tom Cruise
tom_cruise_movies = df[df['name'].str.contains('Tom Cruise', case=False, na=False)]

# Extract the release month from the 'year' column
tom_cruise_movies['ReleaseMonth'] = pd.to_datetime(tom_cruise_movies['year'], format='%Y').dt.month

# Count movies by month and print the data
monthly_counts = tom_cruise_movies['ReleaseMonth'].value_counts().sort_index()

# Create a dictionary to map month numbers to month names
month_names = {
    1: 'January',
    2: 'February',
    3: 'March',
    4: 'April',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'August',
    9: 'September',
    10: 'October',
    11: 'November',
    12: 'December'
}

# Print the results
print("Month\tNumber of Movies")
for month, count in monthly_counts.items():
    print(f"{month_names[month]}\t{count}")
# Out:
# Month	Number of Movies
# January	48
# C:\Users\dell\AppData\Local\Temp\ipykernel_3864\1035236521.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tom_cruise_movies['ReleaseMonth'] = pd.to_datetime(tom_cruise_movies['year'], format='%Y').dt.month
